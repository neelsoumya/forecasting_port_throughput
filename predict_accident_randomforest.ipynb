# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
import os
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
import math

# Functions for random forest classifiers

def train_predict_random_forest_regressor(n_estimators, n_jobs, train, target, test):
    """
    Function to train random forest algorithm
    """

    rf = RandomForestRegressor(n_estimators = n_estimators, n_jobs = n_jobs, oob_score = True)
    print("Training random forest regressor model ...")
    rf.fit(train, target)

    pred_prob_array = rf.predict(test)
    print("Predicting using random forest model (regression)...")
    #[x for x in pred_prob_array]
    #print([x[1] for x in pred_prob_array])

    # Statistics and important features of fit
    print("Statistics and important features of fit\n")
    print(rf.estimators_) # list of DecisionTreeRegressor, The collection of fitted sub-estimators.

    print("Important features\n")
    print(rf.feature_importances_) # : array of shape = [n_features] The feature importances (the higher, the more important the feature).

    print("Number of features\n")
    print(rf.n_features_) #: int The number of features when fit is performed.

    print("The number of outputs when fit is performed\n")
    print(rf.n_outputs_) # : int The number of outputs when fit is performed.

    print("OOB score\n")
    print(rf.oob_score_) # : float Score of the training dataset obtained using an out-of-bag estimate.

    #print(rf.oob_prediction)

    return rf, pred_prob_array


def train_predict_random_forest_classifier(n_estimators, n_jobs, train, target, test):
    """
    Function to train random forest algorithm and also predict
    """

    rf = RandomForestClassifier(n_estimators = n_estimators, n_jobs = n_jobs, oob_score = True)
    print("Training random forest model ...")
    rf.fit(train, target)

    pred_prob_array = rf.predict_proba(test)
    print("Predicting using random forest model ...")
    [x[1] for x in pred_prob_array]
    # print([x[1] for x in pred_prob_array])

    return rf, pred_prob_array



data = pd.read_csv('aggregated_timeseries.csv')

# %%
print(data.describe())
# Out:
#              count  DAY_OF_WEEK  ATMOSPH_COND
# count  3759.000000  3759.000000   3759.000000
# mean     38.150572     3.902634      3.391061
# std       8.525746     2.012888      3.557673
# min       1.000000     0.000000      1.000000
# 25%      32.000000     2.000000      1.000000
# 50%      38.000000     4.000000      1.000000
# 75%      44.000000     6.000000      9.000000
# max      79.000000     7.000000      9.000000

# %%
# first column is targe
target = data.iloc[0:, 0]

# %%
# Convert target to numeric type
target = pd.to_numeric(target)

# %%
# all other columns are training set
train = data.iloc[0:, 1:]

# Convert target to numeric type
train = train.apply(lambda x: pd.to_numeric(x) )

# %%
# train random forest model
print("Training random forest model ...")

test = np.matrix([[2, 1], [3, 1], [4, 1], [5, 1], [6, 1], [7, 1]  ])
# Out:
# Training random forest model ...

# %%
fit_rf_model, pred_prob_array = train_predict_random_forest_regressor(n_estimators=100, n_jobs=2,
                                                                train=train, target=target, test = test)
# Out:
# Training random forest regressor model ...
# Predicting using random forest model (regression)...
# Statistics and important features of fit
#
# [DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1038941789, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1937038525, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1665010902, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=515554772, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=26269094, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1271147063, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1734771003, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=689703210, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1883554539, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=598229489, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=456084504, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1611296558, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1090707782, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1783502168, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=559727725, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1327803336, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=2118647611, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=963480782, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=914433330, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=2081056877, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1325458671, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=716209317, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1337902636, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=927560901, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1668938583, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=807647758, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1701398005, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1858032813, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=405459514, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=26741051, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=220957073, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=226317084, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=830836602, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1559656381, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1756826805, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=934611139, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1090659566, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=847105785, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1242187843, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=36773571, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1626045856, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1087784241, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=128092706, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1633674801, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=303618722, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=534783825, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1074464353, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=537396930, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1940926793, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1942882384, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1067395508, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=261427679, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1070039479, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1586167666, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1666652960, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1194579712, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1427080492, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1486034035, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1054039974, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=743900663, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1599412995, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=798732946, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=458776429, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1271840735, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1696317672, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=239076567, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=963410371, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=485207274, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1237306500, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1321688777, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=813982567, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=260856064, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=271510621, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=520725041, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=31023101, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1400102365, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1953225797, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=2034089530, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=431390330, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=657286372, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1079560866, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1054602549, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=84214221, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=871346442, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1332152160, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1375988699, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=433951877, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1946235664, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1286654140, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=867846653, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=467702446, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=2017914622, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1678140340, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1612791801, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1233872573, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=404107188, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=1425100946, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=870445598, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=842276581, splitter='best'), DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False,
#            random_state=728019648, splitter='best')]
# Important features
#
# [ 0.80595791  0.19404209]
# Number of features
#
# 2
# The number of outputs when fit is performed
#
# 1
# OOB score
#
# 0.0923955604372

# %%
print(pred_prob_array)
# Out:
# [ 35.28010564  37.50122204  37.98302406  40.7272273   40.83695031
#   38.26492146]
